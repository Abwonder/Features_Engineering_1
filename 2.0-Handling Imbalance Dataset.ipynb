# %% [markdown]
# ## Handling Imbalanced Dataset
#
# 1. Up Sampling
# 2. Down Sampling

# %%
import numpy as np
import pandas as pd

# Set the random seed for reproducibility
np.random.seed(123)

# Create a dataframe with two classes
n_samples = 1000
class_0_ratio = 0.9
n_class_0 = int(n_samples * class_0_ratio)
n_class_1 = n_samples - n_class_0

# %%
n_class_0,n_class_1
# Out:
# (900, 100)

# %%
## CREATE MY DATAFRAME WITH IMBALANCED DATASET
class_0 = pd.DataFrame({
    'feature_1': np.random.normal(loc=0, scale=1, size=n_class_0),
    'feature_2': np.random.normal(loc=0, scale=1, size=n_class_0),
    'target': [0] * n_class_0
})

class_1 = pd.DataFrame({
    'feature_1': np.random.normal(loc=2, scale=1, size=n_class_1),
    'feature_2': np.random.normal(loc=2, scale=1, size=n_class_1),
    'target': [1] * n_class_1
})

# %%
class_0
# Out:
#      feature_1  feature_2  target
# 0    -1.774224   0.285744       0
# 1    -1.201377   0.333279       0
# 2     1.096257   0.531807       0
# 3     0.861037  -0.354766       0
# 4    -1.520367  -1.120815       0
# ..         ...        ...     ...
# 895  -0.896718   2.540514       0
# 896   0.812571  -0.082706       0
# 897   0.637361   0.444621       0
# 898   0.332712   1.896404       0
# 899   0.258237   0.237581       0
#
# [900 rows x 3 columns]

# %%
class_1
# Out:
#     feature_1  feature_2  target
# 0   -0.643425   2.571923       1
# 1    1.551009   1.782767       1
# 2    1.641093   2.054318       1
# 3    2.133194   2.155998       1
# 4    1.355758   2.467810       1
# ..        ...        ...     ...
# 95   2.677156   1.092048       1
# 96   2.963404   0.181955       1
# 97   1.621476   1.877267       1
# 98   3.429559   3.794486       1
# 99   3.532273   1.679490       1
#
# [100 rows x 3 columns]

# %%
df=pd.concat([class_0,class_1]).reset_index(drop=True)
df
# Out:
#      feature_1  feature_2  target
# 0    -1.774224   0.285744       0
# 1    -1.201377   0.333279       0
# 2     1.096257   0.531807       0
# 3     0.861037  -0.354766       0
# 4    -1.520367  -1.120815       0
# ..         ...        ...     ...
# 995   2.677156   1.092048       1
# 996   2.963404   0.181955       1
# 997   1.621476   1.877267       1
# 998   3.429559   3.794486       1
# 999   3.532273   1.679490       1
#
# [1000 rows x 3 columns]

# %%
df.describe()
# Out:
#          feature_1    feature_2      target
# count  1000.000000  1000.000000  1000.00000
# mean      0.233658     0.243174     0.10000
# std       1.187297     1.159711     0.30015
# min      -3.066988    -2.551774     0.00000
# 25%      -0.569162    -0.568183     0.00000
# 50%       0.143492     0.132126     0.00000
# 75%       0.874959     0.899164     0.00000
# max       4.799524     4.486085     1.00000

# %%
df.tail()
# Out:
#      feature_1  feature_2  target
# 995   2.677156   1.092048       1
# 996   2.963404   0.181955       1
# 997   1.621476   1.877267       1
# 998   3.429559   3.794486       1
# 999   3.532273   1.679490       1

# %%
df['target'].value_counts()
# Out:
# 0    900
# 1    100
# Name: target, dtype: int64

# %%
## upsampling
df_minority=df[df['target']==1]
df_majority=df[df['target']==0]

df_majority   ### only data in the frame with target in zero (0)
# Out:
#      feature_1  feature_2  target
# 0    -1.774224   0.285744       0
# 1    -1.201377   0.333279       0
# 2     1.096257   0.531807       0
# 3     0.861037  -0.354766       0
# 4    -1.520367  -1.120815       0
# ..         ...        ...     ...
# 895  -0.896718   2.540514       0
# 896   0.812571  -0.082706       0
# 897   0.637361   0.444621       0
# 898   0.332712   1.896404       0
# 899   0.258237   0.237581       0
#
# [900 rows x 3 columns]

# %%
from sklearn.utils import resample
df_minority_upsampled=resample(df_minority,replace=True, #Sample With replacement
         n_samples=len(df_majority),
         random_state=42
        )

# %%
df_minority_upsampled.shape
# Out:
# (900, 3)

# %%
df_minority_upsampled.head()
# Out:
#      feature_1  feature_2  target
# 951   1.125854   1.843917       1
# 992   2.196570   1.397425       1
# 914   1.932170   2.998053       1
# 971   2.272825   3.034197       1
# 960   2.870056   1.550485       1

# %%
df_upsampled=pd.concat([df_majority,df_minority_upsampled])

# %%
df_upsampled['target'].value_counts()
# Out:
# 0    900
# 1    900
# Name: target, dtype: int64

# %% [markdown]
# ## Down Sampling

# %%
import pandas as pd

# Set the random seed for reproducibility
np.random.seed(123)

# Create a dataframe with two classes
n_samples = 1000
class_0_ratio = 0.9
n_class_0 = int(n_samples * class_0_ratio)
n_class_1 = n_samples - n_class_0

class_0 = pd.DataFrame({
    'feature_1': np.random.normal(loc=0, scale=1, size=n_class_0),
    'feature_2': np.random.normal(loc=0, scale=1, size=n_class_0),
    'target': [0] * n_class_0
})

class_1 = pd.DataFrame({
    'feature_1': np.random.normal(loc=2, scale=1, size=n_class_1),
    'feature_2': np.random.normal(loc=2, scale=1, size=n_class_1),
    'target': [1] * n_class_1
})

df = pd.concat([class_0, class_1]).reset_index(drop=True)

# Check the class distribution
print(df['target'].value_counts())
# Out:
# 0    900
# 1    100
# Name: target, dtype: int64

# %%
## downsampling
df_minority=df[df['target']==1]
df_majority=df[df['target']==0]

# %%
from sklearn.utils import resample
df_majority_upsampled=resample(df_minority,replace=True, #Sample With replacement
         n_samples=len(df_majority),
         random_state=42
        )
